# %%
from car_blur import find_car_on_image_and_blur

IMG_PATH = '../data/car-segmentation/images/IMG_20201123_143405.png'
results = find_car_on_image_and_blur(IMG_PATH)
results['mask'].shape
# Out:
# 0: 480x640 1 car, 29.1ms
# Speed: 3.1ms preprocess, 29.1ms inference, 57.7ms postprocess per image at shape (1, 3, 480, 640)
# (750, 1000)

# %%
from utils import plot_results

plot_results(**results)
